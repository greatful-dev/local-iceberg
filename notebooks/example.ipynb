# %%
from utils import get_spark_session

# %%
spark = get_spark_session()
spark.sql('SHOW CATALOGS;').show()
spark.sql('SHOW NAMESPACES IN `iceberg-lake`').show()
# Out:
# +-------------+
# |      catalog|
# +-------------+
# | iceberg-lake|
# |spark_catalog|
# +-------------+
#
# +------------+
# |   namespace|
# +------------+
# |supply_chain|
# +------------+
